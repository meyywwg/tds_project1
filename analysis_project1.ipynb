# %% [markdown]
# <a href="https://colab.research.google.com/github/meyywwg/tds_project1/blob/main/analysis_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#code for scraping
import requests
import csv
import time

# GitHub API token
GITHUB_TOKEN = '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'
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    if company:
        company = company.strip().lstrip('@').upper()
    return company

# Function to fetch users from the GitHub API
def fetch_users(city="Mumbai", min_followers=50):
    users = []
    page = 1

    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        # Break if no more results
        if 'items' not in data or not data['items']:
            break

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })
        page += 1
        time.sleep(1)  # Avoid hitting API rate limits

    return users

# Function to fetch repositories for a user
def fetch_repositories(user_login):
    repositories = []
    page = 1

    while True:
        url = f"https://api.github.com/users/{user_login}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        # Break if no more repositories
        if not repo_data:
            break

        for repo in repo_data:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        # If fewer than 100 repositories are returned, it means we're on the last page
        if len(repo_data) < 100:
            break

        page += 1  # Move to the next page
        time.sleep(1)  # Avoid hitting API rate limits

    return repositories

# Save users to CSV
def save_users_to_csv(users, filename="users.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=users[0].keys())
        writer.writeheader()
        writer.writerows(users)

# Save repositories to CSV
def save_repositories_to_csv(repositories, filename="repositories.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=repositories[0].keys())
        writer.writeheader()
        writer.writerows(repositories)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_users_to_csv(users)
    print(f"Saved {len(users)} users to users.csv")

    print("Fetching repositories...")
    all_repositories = []
    for user in users:
        user_repos = fetch_repositories(user["login"])
        all_repositories.extend(user_repos)
        print(f"Fetched {len(user_repos)} repositories for user {user['login']}")

    save_repositories_to_csv(all_repositories)
    print(f"Saved {len(all_repositories)} repositories to repositories.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Saved 724 users to users.csv
# Fetching repositories...
# Fetched 66 repositories for user ValentineFernandes
# Fetched 37 repositories for user kovidgoyal
# Fetched 113 repositories for user slidenerd
# Fetched 88 repositories for user aryashah2k
# Fetched 11 repositories for user coding-parrot
# Fetched 9 repositories for user gkcs
# Fetched 53 repositories for user darshilparmar
# Fetched 330 repositories for user Kushal334
# Fetched 77 repositories for user ritz078
# Fetched 144 repositories for user PrasoonPratham
# Fetched 35 repositories for user rmehta
# Fetched 69 repositories for user LakshyaDuhoonISU
# Fetched 61 repositories for user dmalvia
# Fetched 41 repositories for user PiyushKumarSingh-90
# Fetched 89 repositories for user mfaisalkhatri
# Fetched 34 repositories for user omsandippatil
# Fetched 17 repositories for user anujvyas
# Fetched 89 repositories for user jalajthanaki
# Fetched 81 repositories for user alisolanki
# Fetched 65 repositories for user ForceGT
# Fetched 139 repositories for user yTakkar
# Fetched 30 repositories for user Sahil4883
# Fetched 52 repositories for user saineshwar
# Fetched 29 repositories for user codescientists
# Fetched 12 repositories for user amangoeliitb
# Fetched 88 repositories for user debugger22
# Fetched 66 repositories for user shifa123
# Fetched 19 repositories for user shyamseshadri
# Fetched 368 repositories for user alokproc
# Fetched 31 repositories for user prasadgujar
# Fetched 6 repositories for user Alexcj10
# Fetched 25 repositories for user rjsamra
# Fetched 18 repositories for user Bhaviktutorials
# Fetched 25 repositories for user aayushi-droid
# Fetched 76 repositories for user sai-sondarkar
# Fetched 13 repositories for user Akshayrane848
# Fetched 8 repositories for user ashkulz
# Fetched 129 repositories for user ankit0183
# Fetched 22 repositories for user theashishgavade
# Fetched 33 repositories for user Suraj-Upadhyay
# Fetched 0 repositories for user CodeChef-Admin
# Fetched 46 repositories for user nabinhait
# Fetched 55 repositories for user sanket-25
# Fetched 78 repositories for user AgentFabulous
# Fetched 32 repositories for user sakshikore16
# Fetched 32 repositories for user HarshilShah
# Fetched 80 repositories for user neobuddy89
# Fetched 25 repositories for user pranitbauva1997
# Fetched 43 repositories for user TanmayGharat1505
# Fetched 104 repositories for user burhanuday
# Fetched 33 repositories for user PremThakareitm
# Fetched 143 repositories for user zemse
# Fetched 63 repositories for user Dhanush-Saji
# Fetched 41 repositories for user dr5hn
# Fetched 137 repositories for user saketkc
# Fetched 143 repositories for user BelieveC
# Fetched 427 repositories for user deadcoder0904
# Fetched 17 repositories for user TejasMedade
# Fetched 193 repositories for user SphericalKat
# Fetched 34 repositories for user ProgrammerGaurav
# Fetched 128 repositories for user eyantra
# Fetched 52 repositories for user shailypriya
# Fetched 37 repositories for user msnimish
# Fetched 29 repositories for user itsnitinr
# Fetched 145 repositories for user arihantbansal
# Fetched 92 repositories for user arunkudiyal
# Fetched 124 repositories for user wajeshubham
# Fetched 75 repositories for user revant
# Fetched 51 repositories for user ruchamahabal
# Fetched 8 repositories for user abdullah768
# Fetched 88 repositories for user veb-101
# Fetched 31 repositories for user amhsirak
# Fetched 152 repositories for user Tlazypanda
# Fetched 36 repositories for user amitavroy
# Fetched 49 repositories for user urmilshroff
# Fetched 25 repositories for user ARYANK-08
# Fetched 39 repositories for user Sankalp679
# Fetched 36 repositories for user mukyasa
# Fetched 89 repositories for user devdatta95
# Fetched 18 repositories for user Prathamesh61
# Fetched 82 repositories for user netchampfaris
# Fetched 26 repositories for user M-Piyush-21
# Fetched 231 repositories for user viveky259259
# Fetched 68 repositories for user dishantzaveri
# Fetched 30 repositories for user mehfoozkhangithub
# Fetched 83 repositories for user sonuprasad66
# Fetched 104 repositories for user rominirani
# Fetched 23 repositories for user swapniljariwala
# Fetched 128 repositories for user raun1997
# Fetched 132 repositories for user rohanverma94
# Fetched 1283 repositories for user vinod1988
# Fetched 32 repositories for user H-unique245
# Fetched 63 repositories for user nihal111
# Fetched 98 repositories for user MoinDalvs
# Fetched 48 repositories for user khansaad1275
# Fetched 28 repositories for user smahesh29
# Fetched 111 repositories for user sonam-niit
# Fetched 43 repositories for user ehtesham-alam
# Fetched 52 repositories for user sovoid
# Fetched 28 repositories for user Gaurang5704
# Fetched 99 repositories for user Ruchip16
# Fetched 55 repositories for user Mandal-21
# Fetched 18 repositories for user prakashjayy
# Fetched 35 repositories for user Ansheel9
# Fetched 40 repositories for user robinrodricks
# Fetched 25 repositories for user zoneAnaS
# Fetched 10 repositories for user sandeepnailwal
# Fetched 60 repositories for user Aman-Mandal
# Fetched 30 repositories for user Singh-Shivani
# Fetched 104 repositories for user ullaskunder3
# Fetched 40 repositories for user surajshetty3416
# Fetched 37 repositories for user moinkhan07
# Fetched 51 repositories for user ajitbohra
# Fetched 35 repositories for user DevanshD3
# Fetched 63 repositories for user bhav1kmaru
# Fetched 68 repositories for user chiragjn
# Fetched 481 repositories for user rajeshpillai
# Fetched 15 repositories for user RohitDhatrak
# Fetched 21 repositories for user umairsy
# Fetched 19 repositories for user Sudarshan2530
# Fetched 91 repositories for user anxkhn
# Fetched 14 repositories for user aman0456
# Fetched 39 repositories for user TheSuranaverse
# Fetched 48 repositories for user Shivajij
# Fetched 46 repositories for user Arya-A-Nair
# Fetched 30 repositories for user mindninjaX
# Fetched 102 repositories for user abhishek305
# Fetched 92 repositories for user pri1311
# Fetched 32 repositories for user AvaisP
# Fetched 7 repositories for user hotstar
# Fetched 130 repositories for user scmmishra
# Fetched 46 repositories for user nurdtechie98
# Fetched 12 repositories for user mukundjha1310
# Fetched 52 repositories for user pal-16
# Fetched 64 repositories for user Jaynil1611
# Fetched 215 repositories for user tusharmath
# Fetched 79 repositories for user susmitpy
# Fetched 59 repositories for user SirusCodes
# Fetched 41 repositories for user arihant-jain-09
# Fetched 66 repositories for user dheerajdlalwani
# Fetched 16 repositories for user kannansingaravelu
# Fetched 69 repositories for user AliabbasMerchant
# Fetched 2499 repositories for user mohd14shoeb
# Fetched 6 repositories for user TechnitiumSoftware
# Fetched 237 repositories for user gat786
# Fetched 12 repositories for user MayureshShilotri
# Fetched 13 repositories for user Saif-sk5417
# Fetched 192 repositories for user tayyabsayyad
# Fetched 13 repositories for user Maalikq
# Fetched 50 repositories for user girishgr8
# Fetched 70 repositories for user hritik5102
# Fetched 54 repositories for user khushboogupta13
# Fetched 45 repositories for user husainhakim
# Fetched 47 repositories for user twilight-warlock
# Fetched 28 repositories for user aaditmshah
# Fetched 13 repositories for user neha-hue
# Fetched 107 repositories for user falcaozane
# Fetched 154 repositories for user abhishekmishragithub
# Fetched 12 repositories for user codewithzosh
# Fetched 72 repositories for user SauravKanchan
# Fetched 112 repositories for user ankitaa19
# Fetched 312 repositories for user mahendra-shinde
# Fetched 67 repositories for user shoaibbhimani
# Fetched 75 repositories for user NSTiwari
# Fetched 20 repositories for user Aakash928
# Fetched 39 repositories for user rakeshpai
# Fetched 18 repositories for user yash0530
# Fetched 33 repositories for user v1k45
# Fetched 91 repositories for user shabh2412
# Fetched 35 repositories for user rishabhpoddar
# Fetched 169 repositories for user Pankaj-Str
# Fetched 126 repositories for user aawezk786
# Fetched 145 repositories for user rajatgupta1998
# Fetched 23 repositories for user know-prashant
# Fetched 90 repositories for user djokester
# Fetched 74 repositories for user Sachin-chaurasiya
# Fetched 77 repositories for user wncc
# Fetched 12 repositories for user hlamba28
# Fetched 26 repositories for user Pargat-Dhanjal
# Fetched 48 repositories for user vishal-android-freak
# Fetched 35 repositories for user devarshishimpi
# Fetched 48 repositories for user parthpanchal123
# Fetched 78 repositories for user tanishk15sharma
# Fetched 102 repositories for user Aatmaj-Zephyr
# Fetched 34 repositories for user Sarahkhan20
# Fetched 71 repositories for user prerana1821
# Fetched 61 repositories for user TanyaChutani
# Fetched 21 repositories for user Kiranwaghmare123
# Fetched 94 repositories for user AmaanC
# Fetched 34 repositories for user vaulstein
# Fetched 16 repositories for user medadeshreyas
# Fetched 29 repositories for user DeltaCoderr
# Fetched 74 repositories for user sounishnath003
# Fetched 21 repositories for user nachiketbhuta
# Fetched 81 repositories for user SnehPandya18
# Fetched 33 repositories for user ankit2341
# Fetched 34 repositories for user kole-swapnil
# Fetched 87 repositories for user khrj
# Fetched 3 repositories for user L4570N3
# Fetched 88 repositories for user tezansahu
# Fetched 29 repositories for user karntrehan
# Fetched 56 repositories for user anirudhjayaraman
# Fetched 39 repositories for user priyankapakhale
# Fetched 0 repositories for user mrsanjuk
# Fetched 16 repositories for user prabhuomkar
# Fetched 191 repositories for user MukulKolpe
# Fetched 15 repositories for user PainKiller3
# Fetched 58 repositories for user aishwaryanevrekar
# Fetched 56 repositories for user kkothari2001
# Fetched 74 repositories for user codingCoffee
# Fetched 44 repositories for user prafulla-codes
# Fetched 22 repositories for user IamSanjayGupta
# Fetched 92 repositories for user rohansx
# Fetched 88 repositories for user PrathmeshSadake
# Fetched 21 repositories for user shushrutsharma
# Fetched 35 repositories for user pandeyanuradha
# Fetched 126 repositories for user vinaynpp
# Fetched 36 repositories for user rishabh1S
# Fetched 38 repositories for user I-am-Sagar
# Fetched 43 repositories for user Hisam-94
# Fetched 252 repositories for user FOSSEE
# Fetched 25 repositories for user pratos
# Fetched 77 repositories for user AlfiyaSiddique
# Fetched 29 repositories for user deepeshgarg007
# Fetched 17 repositories for user dominicpereira92
# Fetched 146 repositories for user hrithikwins
# Fetched 39 repositories for user sengupta
# Fetched 15 repositories for user abhishekluv
# Fetched 139 repositories for user vaibhavgeek
# Fetched 81 repositories for user bhism
# Fetched 52 repositories for user sumanentc
# Fetched 105 repositories for user JadenFurtado
# Fetched 30 repositories for user dream11
# Fetched 21 repositories for user kasem-sm
# Fetched 72 repositories for user kaushikb11
# Fetched 23 repositories for user learnNcode
# Fetched 174 repositories for user Yh010
# Fetched 25 repositories for user yuvraj24
# Fetched 51 repositories for user utsavk28
# Fetched 173 repositories for user zaidmukaddam
# Fetched 40 repositories for user anamansari062
# Fetched 25 repositories for user FreeBirdsCrew
# Fetched 83 repositories for user computingfreak
# Fetched 48 repositories for user VitthalGund
# Fetched 109 repositories for user basic-coder
# Fetched 65 repositories for user ur0
# Fetched 18 repositories for user anshrathod
# Fetched 7 repositories for user WadhwaniAI
# Fetched 35 repositories for user pateljannat
# Fetched 177 repositories for user meetmangukiya
# Fetched 30 repositories for user KritiThakrar
# Fetched 36 repositories for user gopala-kr
# Fetched 14 repositories for user arnab-datta
# Fetched 26 repositories for user fehmida99
# Fetched 75 repositories for user Jatin-8898
# Fetched 14 repositories for user RohitDSawant
# Fetched 59 repositories for user KartikSoneji
# Fetched 16 repositories for user jamesmt-95
# Fetched 40 repositories for user orvil1026
# Fetched 78 repositories for user sand000
# Fetched 27 repositories for user hardikbansal
# Fetched 22 repositories for user RajGhugare19
# Fetched 57 repositories for user raveenakale475
# Fetched 53 repositories for user Rahul5303
# Fetched 64 repositories for user jhasuraj01
# Fetched 27 repositories for user siddikgitt
# Fetched 44 repositories for user nishit130
# Fetched 47 repositories for user Gaurav-Punjabi
# Fetched 17 repositories for user Rohit-M-Roy
# Fetched 128 repositories for user shivani0986
# Fetched 65 repositories for user AnkurGel
# Fetched 92 repositories for user WilfredAlmeida
# Fetched 35 repositories for user nextchamp-saqib
# Fetched 45 repositories for user exaby73
# Fetched 53 repositories for user suvadityamuk
# Fetched 42 repositories for user anushka-2001
# Fetched 17 repositories for user gitesh8
# Fetched 37 repositories for user jhamadhav
# Fetched 44 repositories for user aakashratha1006
# Fetched 86 repositories for user siddharthrajaraja
# Fetched 34 repositories for user srajangarg
# Fetched 47 repositories for user Neel-Shah-29
# Fetched 84 repositories for user touhidshaikh
# Fetched 50 repositories for user PrerakGada
# Fetched 38 repositories for user 0xRoneet
# Fetched 31 repositories for user owaisshassan
# Fetched 137 repositories for user simplysabir
# Fetched 37 repositories for user ombhilare999
# Fetched 8 repositories for user thecybertix
# Fetched 11 repositories for user jahnvisikligar
# Fetched 110 repositories for user SikandarJODD
# Fetched 15 repositories for user aakriti-sharma
# Fetched 16 repositories for user ryanjon2040
# Fetched 43 repositories for user Saif807380
# Fetched 20 repositories for user shiblisec
# Fetched 96 repositories for user uzairansari11
# Fetched 9 repositories for user shubhamrasam
# Fetched 25 repositories for user hrishi84
# Fetched 45 repositories for user fayeed
# Fetched 37 repositories for user shahshubh
# Fetched 89 repositories for user slmsshk
# Fetched 31 repositories for user Abhijeetrkushwaha
# Fetched 43 repositories for user himanshu-03
# Fetched 45 repositories for user Syn3rman
# Fetched 31 repositories for user ayushhharyann007
# Fetched 30 repositories for user rubyruins
# Fetched 82 repositories for user pk-218
# Fetched 68 repositories for user kambleaa007
# Fetched 39 repositories for user nitinhayaran
# Fetched 48 repositories for user vazzup
# Fetched 26 repositories for user abhishekyadav001
# Fetched 29 repositories for user dipeshpatil
# Fetched 117 repositories for user SarveshLimaye
# Fetched 40 repositories for user Candida18
# Fetched 24 repositories for user rohan28107
# Fetched 79 repositories for user Reefaq
# Fetched 57 repositories for user error404-sp
# Fetched 104 repositories for user Abhimishra2424
# Fetched 109 repositories for user GaneshSrambikal
# Fetched 37 repositories for user romabulani
# Fetched 35 repositories for user bymayanksingh
# Fetched 23 repositories for user soumendra
# Fetched 21 repositories for user mahanvyakti
# Fetched 47 repositories for user hritik2002
# Fetched 9 repositories for user MIDHUNTA30
# Fetched 31 repositories for user adityahase
# Fetched 178 repositories for user therealharpaljadeja
# Fetched 35 repositories for user meshtag
# Fetched 55 repositories for user Vivek-Nemade
# Fetched 38 repositories for user sumit6675
# Fetched 42 repositories for user shaikhsajid1111
# Fetched 90 repositories for user rahil471
# Fetched 15 repositories for user Bharvi-Sampat
# Fetched 32 repositories for user tanS30
# Fetched 78 repositories for user simranjeet97
# Fetched 37 repositories for user vlakhani28
# Fetched 94 repositories for user hridayK
# Fetched 1 repositories for user amitsingh0002
# Fetched 23 repositories for user akshatshah21
# Fetched 15 repositories for user Neerav-Khatri
# Fetched 25 repositories for user sunnypatel165
# Fetched 47 repositories for user Dinesh2510
# Fetched 93 repositories for user sahilpabale
# Fetched 92 repositories for user eaglewarrior
# Fetched 54 repositories for user devanshj
# Fetched 57 repositories for user prikeshsavla
# Fetched 30 repositories for user Dev-faiz
# Fetched 68 repositories for user rohanchikorde
# Fetched 69 repositories for user vishalgaddam873
# Fetched 18 repositories for user VikeshHinge
# Fetched 33 repositories for user shubhambhole99
# Fetched 22 repositories for user Sheldon-CodeIt
# Fetched 30 repositories for user aryan-parmar
# Fetched 90 repositories for user anaskhan28
# Fetched 23 repositories for user techcsispit
# Fetched 44 repositories for user YelveTejas
# Fetched 135 repositories for user Zeo-shark
# Fetched 211 repositories for user amite
# Fetched 49 repositories for user sirtaj786
# Fetched 76 repositories for user Hamdrive
# Fetched 17 repositories for user ankit25821
# Fetched 43 repositories for user SagarGaniga
# Fetched 114 repositories for user heytulsiprasad
# Fetched 39 repositories for user indranildchandra
# Fetched 33 repositories for user EshikaShah
# Fetched 34 repositories for user ashish2
# Fetched 70 repositories for user GauravSahani1417
# Fetched 23 repositories for user nehakadam
# Fetched 70 repositories for user prateekmaj21
# Fetched 54 repositories for user Om-jannu
# Fetched 40 repositories for user Vikr-182
# Fetched 112 repositories for user jitendra3109
# Fetched 53 repositories for user panditakshay402
# Fetched 66 repositories for user chait04
# Fetched 19 repositories for user RajneeshSingh007
# Fetched 30 repositories for user theIYD
# Fetched 121 repositories for user vivek12345
# Fetched 28 repositories for user sarveshchavan7
# Fetched 45 repositories for user rajrajhans
# Fetched 59 repositories for user Shashvat6264
# Fetched 26 repositories for user sunchushivaaa
# Fetched 53 repositories for user mizanxali
# Fetched 18 repositories for user rakeshrakeshyadav
# Fetched 93 repositories for user mayuur
# Fetched 35 repositories for user alkhalidsardar
# Fetched 41 repositories for user nikhil-RGB
# Fetched 58 repositories for user thouseef-hamza
# Fetched 58 repositories for user Altafalam3
# Fetched 1 repositories for user shaikhanas237
# Fetched 36 repositories for user Piyush-Keshri
# Fetched 15 repositories for user Sandeepyadav14
# Fetched 21 repositories for user QuantInsti
# Fetched 77 repositories for user jwalapc
# Fetched 61 repositories for user manju145
# Fetched 23 repositories for user tanmay-pro
# Fetched 67 repositories for user 1407arjun
# Fetched 61 repositories for user shaileshwebdeveloper
# Fetched 74 repositories for user zoe-abedi
# Fetched 359 repositories for user Chitrank-Dixit
# Fetched 89 repositories for user balvinderz
# Fetched 32 repositories for user d33vanshu
# Fetched 30 repositories for user PremBharwani
# Fetched 9 repositories for user RajeshPatkar
# Fetched 64 repositories for user Pradyumancoder
# Fetched 54 repositories for user neilLasrado
# Fetched 32 repositories for user Zivi09
# Fetched 17 repositories for user kalpitagavas
# Fetched 13 repositories for user Omchand27
# Fetched 18 repositories for user PriyaSarkarIITB
# Fetched 22 repositories for user ayush-tiwari57
# Fetched 17 repositories for user Mohd-Ali2
# Fetched 76 repositories for user murtaza98
# Fetched 24 repositories for user yash-chad
# Fetched 4 repositories for user ShreyasZare
# Fetched 24 repositories for user tarantulass
# Fetched 36 repositories for user shariquerik
# Fetched 12 repositories for user DetainedDeveloper
# Fetched 96 repositories for user someshfengde
# Fetched 44 repositories for user vijayjoshi16
# Fetched 26 repositories for user DataRaj
# Fetched 52 repositories for user subhamagrawal7
# Fetched 192 repositories for user dineshtamang14
# Fetched 22 repositories for user PoojaRathod5
# Fetched 23 repositories for user megh-bari
# Fetched 37 repositories for user SRA-VJTI
# Fetched 26 repositories for user Jash-Shah
# Fetched 33 repositories for user EshanTrivedi21
# Fetched 110 repositories for user RATTLESNAKE-VIPER
# Fetched 32 repositories for user darshanc99
# Fetched 62 repositories for user pulkitsharma07
# Fetched 131 repositories for user arbazkhan971
# Fetched 90 repositories for user someshkoli
# Fetched 40 repositories for user pritishmishra703
# Fetched 30 repositories for user gulam160
# Fetched 12 repositories for user introwit
# Fetched 19 repositories for user AnmolSahota
# Fetched 46 repositories for user ShashankGupta10
# Fetched 10 repositories for user pankajparashar-zz
# Fetched 44 repositories for user RusherRG
# Fetched 18 repositories for user kLinus
# Fetched 86 repositories for user mohitmun
# Fetched 58 repositories for user Zanark
# Fetched 12 repositories for user psndna88
# Fetched 37 repositories for user sarvesh2902
# Fetched 31 repositories for user mavrick08
# Fetched 44 repositories for user abunickabhi
# Fetched 18 repositories for user Shibshankar01
# Fetched 39 repositories for user gavandivya
# Fetched 26 repositories for user ananikets18
# Fetched 249 repositories for user Aveesh52-zz
# Fetched 36 repositories for user TheComputerM
# Fetched 31 repositories for user rozodkarbharat
# Fetched 23 repositories for user adityaguptai
# Fetched 14 repositories for user dcs1997
# Fetched 77 repositories for user hannansatopay
# Fetched 62 repositories for user karan28598
# Fetched 12 repositories for user sakship31
# Fetched 9 repositories for user sandeepshetty
# Fetched 192 repositories for user sandiprb
# Fetched 173 repositories for user Pratham82
# Fetched 59 repositories for user resyfer
# Fetched 59 repositories for user RawSanj
# Fetched 33 repositories for user Jasmin2895
# Fetched 19 repositories for user aryanveturekar
# Fetched 22 repositories for user aryan1113
# Fetched 94 repositories for user milanpanchal
# Fetched 38 repositories for user technoweirds
# Fetched 1 repositories for user KJSCE-SVU
# Fetched 48 repositories for user uniyalabhishek
# Fetched 69 repositories for user sharur7
# Fetched 41 repositories for user Thakur-Govind
# Fetched 108 repositories for user psankhe28
# Fetched 75 repositories for user Divyanshu-Modi
# Fetched 45 repositories for user kumarmj
# Fetched 55 repositories for user vikassuresh4397
# Fetched 8 repositories for user TSMaitry
# Fetched 26 repositories for user Jay4Codes
# Fetched 118 repositories for user haydencordeiro
# Fetched 56 repositories for user srikantpatnaik
# Fetched 51 repositories for user dsrao711
# Fetched 9 repositories for user ArjoshwaDmello
# Fetched 30 repositories for user CommunityOfCoders
# Fetched 6 repositories for user Zeel2163
# Fetched 35 repositories for user Vishesh-Pandey
# Fetched 51 repositories for user OmkarPh
# Fetched 23 repositories for user prashants
# Fetched 9 repositories for user kevinnadar22
# Fetched 30 repositories for user Mukesh-Sharma400
# Fetched 157 repositories for user geeekgod
# Fetched 11 repositories for user Aali34362
# Fetched 35 repositories for user vabhishek-me
# Fetched 123 repositories for user gunjan1909
# Fetched 48 repositories for user Deepa-chaurasiya01
# Fetched 35 repositories for user RugvedB
# Fetched 14 repositories for user nisha270
# Fetched 14 repositories for user Geletinousamigo
# Fetched 39 repositories for user prajapatidheeraj1999
# Fetched 32 repositories for user YourTechBud
# Fetched 67 repositories for user yashbhangale
# Fetched 22 repositories for user whoisaditya
# Fetched 54 repositories for user IamLucif3r
# Fetched 48 repositories for user rahulyadav826870
# Fetched 86 repositories for user amrendrakind
# Fetched 40 repositories for user meetalik8
# Fetched 68 repositories for user NitkarshChourasia
# Fetched 35 repositories for user follow2vivek
# Fetched 30 repositories for user Alkaison
# Fetched 45 repositories for user smitsekhadiaa
# Fetched 82 repositories for user jay-2000
# Fetched 44 repositories for user gauravkulkarni96
# Fetched 137 repositories for user manasRK
# Fetched 54 repositories for user ajduke
# Fetched 44 repositories for user soham2710
# Fetched 60 repositories for user shantanuo
# Fetched 102 repositories for user Jatin7385
# Fetched 32 repositories for user KaustubhDamania
# Fetched 37 repositories for user quantumcoder121
# Fetched 13 repositories for user chtnnh
# Fetched 56 repositories for user ShankyTiwari
# Fetched 30 repositories for user dutiyesh
# Fetched 32 repositories for user ArionMiles
# Fetched 85 repositories for user rohanmathur91
# Fetched 77 repositories for user Rishabh672003
# Fetched 21 repositories for user Aamir-Ansari-almost
# Fetched 22 repositories for user Ananyapam7
# Fetched 40 repositories for user chirag64
# Fetched 72 repositories for user SanjaySargam
# Fetched 43 repositories for user aakashjhawar
# Fetched 82 repositories for user JapneetRajput
# Fetched 116 repositories for user lem0n4id
# Fetched 37 repositories for user BHAGATBHAGYASHREE
# Fetched 14 repositories for user narender-rk10
# Fetched 39 repositories for user SUJALGPM
# Fetched 24 repositories for user Malik04121
# Fetched 12 repositories for user nimish1001
# Fetched 28 repositories for user saurabhshahane4
# Fetched 58 repositories for user dev-akhilesh
# Fetched 77 repositories for user rohankokkula
# Fetched 28 repositories for user Spyy004
# Fetched 38 repositories for user Reuben27
# Fetched 41 repositories for user cybot-des
# Fetched 107 repositories for user ayush1999
# Fetched 57 repositories for user tambegaurav
# Fetched 54 repositories for user dwij2812
# Fetched 59 repositories for user archanpatkar
# Fetched 20 repositories for user RajSharma877
# Fetched 46 repositories for user starlight5234
# Fetched 12 repositories for user aayushisah
# Fetched 32 repositories for user OjasKarmarkar
# Fetched 48 repositories for user aayushah711
# Fetched 48 repositories for user bedantH
# Fetched 19 repositories for user subhipandey
# Fetched 18 repositories for user iamsuyashh
# Fetched 26 repositories for user ShyrenMore
# Fetched 14 repositories for user souvik131
# Fetched 85 repositories for user neophyt3
# Fetched 27 repositories for user nilesh-patil
# Fetched 45 repositories for user mygoal-javadeveloper
# Fetched 22 repositories for user SaketThota
# Fetched 48 repositories for user Harshvartak
# Fetched 48 repositories for user Coollaitar
# Fetched 98 repositories for user chankeypathak
# Fetched 52 repositories for user masterchief164
# Fetched 63 repositories for user Dare-marvel
# Fetched 47 repositories for user ninadnaik10
# Fetched 72 repositories for user Jetsoanalin
# Fetched 47 repositories for user mronian
# Fetched 25 repositories for user kalindkaria
# Fetched 13 repositories for user 9vishwashah
# Fetched 20 repositories for user JayeshThakare98
# Fetched 11 repositories for user Mithil467
# Fetched 3 repositories for user taabishk
# Fetched 58 repositories for user khurramrizvi
# Fetched 42 repositories for user yashtailor
# Fetched 17 repositories for user Digital21
# Fetched 12 repositories for user sanket-kumbhare
# Fetched 60 repositories for user akasranjan005
# Fetched 29 repositories for user Suryansh777777
# Fetched 55 repositories for user rojaAchary
# Fetched 48 repositories for user AryanShinde
# Fetched 24 repositories for user jainakshansh
# Fetched 71 repositories for user ajitjha393
# Fetched 27 repositories for user RikamPalkar
# Fetched 21 repositories for user jaypatelll1
# Fetched 14 repositories for user eewsagar
# Fetched 0 repositories for user whitechashma237
# Fetched 71 repositories for user fresearchgroup
# Fetched 38 repositories for user sudonitin
# Fetched 50 repositories for user alistair0111
# Fetched 56 repositories for user yash-nisar
# Fetched 56 repositories for user arpitnath
# Fetched 44 repositories for user Zaeem20
# Fetched 197 repositories for user backtrackbaba
# Fetched 50 repositories for user rahulsingh2312
# Fetched 32 repositories for user jasmit21
# Fetched 49 repositories for user ericadsouxa
# Fetched 48 repositories for user Adarsh-k0802
# Fetched 24 repositories for user Swap76
# Fetched 109 repositories for user AdiPat
# Fetched 25 repositories for user SupreethBaliga
# Fetched 38 repositories for user KanadeAditya
# Fetched 274 repositories for user kharatramesh
# Fetched 79 repositories for user hasnain2808
# Fetched 15 repositories for user yashtazor
# Fetched 67 repositories for user codef0rmer
# Fetched 54 repositories for user ivank
# Fetched 31 repositories for user KCmean
# Fetched 26 repositories for user Pramodh-G
# Fetched 24 repositories for user bevatsal1122
# Fetched 9 repositories for user ackotech
# Fetched 88 repositories for user GyaneshSamanta
# Fetched 78 repositories for user Vishruta-Patil
# Fetched 22 repositories for user shaggyyy2002
# Fetched 28 repositories for user kumarsonsoff3
# Fetched 135 repositories for user deependhulla
# Fetched 60 repositories for user hayat-tamboli
# Fetched 92 repositories for user PreetiW
# Fetched 88 repositories for user devamitjha
# Fetched 24 repositories for user kj-95
# Fetched 92 repositories for user utkarshsingh99
# Fetched 42 repositories for user deepanshu2506
# Fetched 61 repositories for user ajinkya007
# Fetched 37 repositories for user staticshreyas
# Fetched 59 repositories for user Abhiroop25902
# Fetched 58 repositories for user PrachetShah
# Fetched 26 repositories for user Sandesh1013
# Fetched 59 repositories for user Jigsaw-23122002
# Fetched 6 repositories for user SamsonSeemal
# Fetched 7 repositories for user algobulls
# Fetched 39 repositories for user harshchi19
# Fetched 34 repositories for user Sarthak3003
# Fetched 70 repositories for user Jaishree2310
# Fetched 47 repositories for user raju249
# Fetched 9 repositories for user sairam1411
# Fetched 17 repositories for user Rakeshistom
# Fetched 1 repositories for user nischal
# Fetched 18 repositories for user devishworld
# Fetched 34 repositories for user archeelp
# Fetched 60 repositories for user codertech120386
# Fetched 6 repositories for user vinitsangoi
# Fetched 20 repositories for user rkkirpane
# Fetched 18 repositories for user amoghsinkar910
# Fetched 30 repositories for user sank8dalvi
# Fetched 39 repositories for user qureai
# Fetched 22 repositories for user amit-y11
# Fetched 64 repositories for user devkakeri06
# Fetched 25 repositories for user NinadRao0707
# Fetched 51 repositories for user theProgrammerDavid
# Fetched 87 repositories for user nileshprasad137
# Fetched 16 repositories for user zubinmehta
# Fetched 27 repositories for user 5arthak01
# Fetched 30 repositories for user meghrathod
# Fetched 27 repositories for user Salonee-Jain
# Fetched 44 repositories for user pruthvirajp04
# Fetched 66 repositories for user sahilnare
# Fetched 85 repositories for user viraj-s15
# Fetched 12 repositories for user nik9hil
# Fetched 39 repositories for user Saravana08
# Fetched 12 repositories for user Ayaz-01
# Fetched 66 repositories for user horsemaker
# Fetched 21 repositories for user SamFusedBits
# Fetched 181 repositories for user ZakiMohammed
# Fetched 69 repositories for user Inv3nt0r1
# Fetched 30 repositories for user rohan-mistry
# Fetched 18 repositories for user abhi0402
# Fetched 15 repositories for user vmundra
# Fetched 15 repositories for user Aafiya-H
# Fetched 33 repositories for user meet-gagan
# Fetched 81 repositories for user Anuragmaurya-code
# Fetched 45 repositories for user miteshgoplani
# Fetched 48 repositories for user AmeyaDaddikar
# Fetched 73 repositories for user SG-Kolipyaka
# Fetched 72 repositories for user darshjain
# Fetched 54 repositories for user ShruAgarwal
# Fetched 25 repositories for user ulhas
# Fetched 54 repositories for user a7r3
# Fetched 48 repositories for user azizhk
# Fetched 82 repositories for user itsjwala
# Fetched 49 repositories for user MaheraFurniturewala
# Fetched 76 repositories for user Piyush-linux
# Fetched 57 repositories for user ethicalrushi
# Fetched 24 repositories for user shizothetechie
# Fetched 6 repositories for user geekvijay
# Fetched 52 repositories for user SidJain1412
# Fetched 41 repositories for user AkshatBhat
# Fetched 57 repositories for user Nachimak28
# Fetched 36 repositories for user harshaldulera
# Fetched 33 repositories for user chakshu-dhannawat
# Fetched 7 repositories for user mavericknihar
# Fetched 61 repositories for user Kingbond470
# Fetched 133 repositories for user vidyesh95
# Fetched 61 repositories for user amardaxini
# Fetched 559 repositories for user patilswapnilv
# Fetched 101 repositories for user koolgax99
# Fetched 76 repositories for user svs
# Fetched 36 repositories for user Zemotacqy
# Fetched 31 repositories for user Honey14
# Fetched 58 repositories for user aniketparate
# Fetched 62 repositories for user Davekibh
# Fetched 100 repositories for user SiddhiGolatkar
# Fetched 29 repositories for user yukta12
# Fetched 17 repositories for user midd-96
# Fetched 44 repositories for user arpitajadhav9
# Fetched 48 repositories for user Elysian01
# Fetched 18 repositories for user vvignesh17
# Fetched 21 repositories for user SurajLad
# Fetched 59 repositories for user t007rushi
# Fetched 36 repositories for user Prachi-Jamdade
# Fetched 6 repositories for user Sakshi107
# Fetched 29 repositories for user pujanm
# Fetched 7 repositories for user jayeshk7
# Fetched 63 repositories for user adarshxs
# Fetched 15 repositories for user RushabhM03
# Fetched 26 repositories for user AmiMunshi
# Fetched 54 repositories for user sarthak0714
# Fetched 36 repositories for user adwait-thattey
# Fetched 15 repositories for user mohitagrawal22
# Fetched 57 repositories for user hemant069
# Fetched 81 repositories for user vjFaLk
# Fetched 3 repositories for user mufassirkazi
# Fetched 55 repositories for user mdjawedh022
# Fetched 72 repositories for user sonusathyadas
# Fetched 8 repositories for user vidit0210
# Fetched 9 repositories for user krittikaiitb
# Saved 44182 repositories to repositories.csv

# %%
#Q1
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Sort by followers and get top 5
top_users = users_df.sort_values(by='followers', ascending=False).head(5)

# Extract logins
top_logins = top_users['login'].tolist()
result = ', '.join(top_logins)

print(result)
# Out:
# ValentineFernandes, kovidgoyal, slidenerd, aryashah2k, coding-parrot

# %%
#Q2
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Convert created_at to datetime
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Sort by created_at and get the earliest 5 users
earliest_users = users_df.sort_values(by='created_at').head(5)

# Extract logins
earliest_logins = earliest_users['login'].tolist()
result = ', '.join(earliest_logins)

print(result)
# Out:
# ivank, sandeepshetty, svs, nitinhayaran, nischal

# %%
#Q3
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Filter out missing license names
repositories_df = repositories_df[repositories_df['license_name'].notna()]

# Count occurrences of each license
license_counts = repositories_df['license_name'].value_counts()

# Get the top 3 licenses
top_licenses = license_counts.head(3).index.tolist()

# Join the license names in order
result = ', '.join(top_licenses)

print(result)
# Out:
# mit, apache-2.0, other

# %%
#Q4
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Count occurrences of each company
company_counts = users_df['company'].value_counts()

# Get the company with the highest count
most_common_company = company_counts.idxmax()
most_common_count = company_counts.max()

print(f"The majority of developers work at: {most_common_company} with {most_common_count} developers.")
# Out:
# The majority of developers work at: MASAI SCHOOL with 14 developers.

# %%
#Q5
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Count occurrences of each programming language, ignoring missing values
language_counts = repositories_df['language'].value_counts()

# Get the most popular programming language
most_popular_language = language_counts.idxmax()
most_popular_count = language_counts.max()

print(f"The most popular programming language is: {most_popular_language} with {most_popular_count} repositories.")
# Out:
# The most popular programming language is: JavaScript with 8305 repositories.

# %%
#Q6
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')
repositories_df = pd.read_csv('repositories.csv')

# Convert created_at to datetime and filter users who joined after 2020
users_df['created_at'] = pd.to_datetime(users_df['created_at'])
recent_users = users_df[users_df['created_at'] > '2020-01-01']

# Get the logins of recent users
recent_user_logins = recent_users['login'].tolist()

# Filter repositories by these users
recent_repositories = repositories_df[repositories_df['login'].isin(recent_user_logins)]

# Count occurrences of each programming language
language_counts = recent_repositories['language'].value_counts()

# Get the second most popular programming language
second_most_popular_language = language_counts.nlargest(2).index[1]
second_most_popular_count = language_counts.nlargest(2).values[1]

print(f"The second most popular programming language among users who joined after 2020 is: {second_most_popular_language} with {second_most_popular_count} repositories.")
# Out:
# The second most popular programming language among users who joined after 2020 is: HTML with 1304 repositories.

# %%
#Q7
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Group by programming language and calculate the average stars
average_stars = repositories_df.groupby('language')['stargazers_count'].mean()

# Identify the language with the highest average stars
highest_average_language = average_stars.idxmax()
highest_average_value = average_stars.max()

print(f"The programming language with the highest average number of stars per repository is: {highest_average_language} with an average of {highest_average_value:.2f} stars.")
# Out:
# The programming language with the highest average number of stars per repository is: TSQL with an average of 571.00 stars.

# %%
#Q8
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Calculate leader_strength
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort by leader_strength and get the top 5
top_leaders = users_df.sort_values(by='leader_strength', ascending=False).head(5)

# Extract logins
top_logins = top_leaders['login'].tolist()
result = ', '.join(top_logins)

print(result)
# Out:
# kovidgoyal, coding-parrot, gkcs, slidenerd, dmalvia

# %%
#Q9
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Calculate the correlation between followers and public repositories
correlation = users_df['followers'].corr(users_df['public_repos'])

print(f"The correlation between the number of followers and the number of public repositories is: {correlation:.3f}")
# Out:
# The correlation between the number of followers and the number of public repositories is: 0.034

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
users_df = pd.read_csv('users.csv')

# Check for NaNs and infinite values in the relevant columns
print("Checking for NaNs or infinite values in public_repos and followers...")
print(users_df[['public_repos', 'followers']].isnull().sum())  # Count of NaNs
print((~users_df[['public_repos', 'followers']].isin([float('inf'), float('-inf')])).all())  # Check for infs

# Option 1: Drop rows with NaN or infinite values
users_df = users_df.dropna(subset=['public_repos', 'followers'])
users_df = users_df[(users_df['public_repos'] != float('inf')) & (users_df['public_repos'] != float('-inf'))]
users_df = users_df[(users_df['followers'] != float('inf')) & (users_df['followers'] != float('-inf'))]

# Define the independent variable (X) and dependent variable (Y)
X = users_df['public_repos']
Y = users_df['followers']

# Add a constant to the independent variable (for the intercept)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(Y, X).fit()

# Get the summary of the regression results
summary = model.summary()

# Extract the coefficient for public_repos
additional_followers_per_repo = model.params['public_repos']

print(f"Regression Results:\n{summary}")
print(f"Estimated additional followers per additional public repository: {additional_followers_per_repo:.3f}")
# Out:
# Checking for NaNs or infinite values in public_repos and followers...
# public_repos    1
# followers       1
# dtype: int64
# public_repos    True
# followers       True
# dtype: bool
# Regression Results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              followers   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8467
# Date:                Thu, 31 Oct 2024   Prob (F-statistic):              0.358
# Time:                        14:10:44   Log-Likelihood:                -5238.0
# No. Observations:                 724   AIC:                         1.048e+04
# Df Residuals:                     722   BIC:                         1.049e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          150.6747     14.142     10.655      0.000     122.911     178.438
# public_repos     0.1001      0.109      0.920      0.358      -0.113       0.314
# ==============================================================================
# Omnibus:                     1179.720   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           450009.804
# Skew:                           9.956   Prob(JB):                         0.00
# Kurtosis:                     123.503   Cond. No.                         147.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Estimated additional followers per additional public repository: 0.100

# %%
#Q11
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')


# Calculate the correlation directly
correlation = repositories_df['has_projects'].corr(repositories_df['has_wiki'])

print(f"The correlation between having projects enabled and having a wiki enabled is: {correlation:.3f}")
# Out:
# The correlation between having projects enabled and having a wiki enabled is: 0.154

# %%
#Q12
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate average following for both groups
average_hireable_following = hireable_users['following'].mean()
average_non_hireable_following = non_hireable_users['following'].mean()

# Calculate the difference
difference = average_hireable_following - average_non_hireable_following

# Print the result rounded to three decimal places
print(f'Difference in average following (hireable - non-hireable): {difference:.3f}')
# Out:
# Difference in average following (hireable - non-hireable): 8.175

# %%
#Q13
import pandas as pd
import statsmodels.api as sm

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna()]

# Calculate the length of the bio in words
#users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()

users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))


# Prepare the data for regression
X = users_with_bios['bio_word_count']  # Independent variable
y = users_with_bios['followers']        # Dependent variable

# Add a constant to the independent variable for the regression
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the regression slope (coefficient for bio_word_count)
slope = model.params['bio_word_count']

# Print the slope rounded to three decimal places
print(f'Regression slope of followers on bio word count: {slope:.3f}')
# Out:
# Regression slope of followers on bio word count: -0.378
# <ipython-input-17-0d29c74c7506>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))

# %%
#Q14
import pandas as pd

# Load the repositories data from the CSV file
repos_df = pd.read_csv('repositories.csv')

# Convert the created_at column to datetime
repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

# Filter for weekend days (Saturday: 5, Sunday: 6)
weekend_repos = repos_df[repos_df['created_at'].dt.dayofweek.isin([5, 6])]

# Count the number of repositories created by each user
top_users = weekend_repos['login'].value_counts().head(5)

# Get the top 5 users' logins in order
top_users_logins = ', '.join(top_users.index)

# Print the result
print(f'Top 5 users who created the most repositories on weekends: {top_users_logins}')
# Out:
# Top 5 users who created the most repositories on weekends: mohd14shoeb, vinod1988, Kushal334, patilswapnilv, alokproc

# %%
#Q15
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Total number of users
total_users = len(users_df)

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate the fraction of users with email in both groups
fraction_hireable_with_email = hireable_users['email'].notna().mean()
fraction_non_hireable_with_email = non_hireable_users['email'].notna().mean()

# Calculate the difference
difference = fraction_hireable_with_email - fraction_non_hireable_with_email

# Print the result rounded to three decimal places
print(f'Difference in fraction of users with email: {difference:.3f}')
# Out:
# Difference in fraction of users with email: 0.223

# %%
#Q16
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without names
valid_users = users_df[users_df['name'].notna()]

# Extract surnames (last word in name)
valid_users['surname'] = valid_users['name'].str.strip().str.split().str[-1]

# Count occurrences of each surname
surname_counts = valid_users['surname'].value_counts()

# Find the most common surname(s)
max_count = surname_counts.max()
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort surnames alphabetically
most_common_surnames.sort()

# Count users with the most common surname
number_of_users = max_count

# Print results
most_common_surnames_str = ', '.join(most_common_surnames)
print(f'Most common surname(s): {most_common_surnames_str}')
print(f'Number of users with the most common surname: {number_of_users}')
# Out:
# Most common surname(s): Singh
# Number of users with the most common surname: 17
# <ipython-input-20-dc0f22873520>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_users['surname'] = valid_users['name'].str.strip().str.split().str[-1]
